# %%
# Out:
# ('4.40.2', '0.30.1')

# %%
# Out:
# 100%|██████████| 260/260 [00:21<00:00, 11.97it/s]
# Images shape: (2975, 268, 182, 3)
# Labels shape: (2975, 23)

# %%
# Out:
# Training images shape: (2380, 268, 182, 3)
# Training labels shape: (2380, 23)
# Testing images shape: (595, 268, 182, 3)
# Testing labels shape: (595, 23)
#           Label  Train Distribution  Test Distribution
# 0        Action                 114                 33
# 1     Adventure                 224                 67
# 2     Animation                  54                 12
# 3     Biography                  93                 21
# 4        Comedy                 759                184
# 5         Crime                 386                 99
# 6   Documentary                  27                 10
# 7         Drama                1405                355
# 8        Family                 110                 17
# 9       Fantasy                 100                 31
# 10    Film-Noir                 201                 52
# 11      History                 125                 35
# 12       Horror                 108                 28
# ...

# %%
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 2380
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 595
#     })
# })
# ...

# %%
# Out:
# Map:   0%|          | 0/2380 [00:00<?, ? examples/s]
